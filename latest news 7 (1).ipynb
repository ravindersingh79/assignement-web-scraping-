# %%
import requests as re
from bs4 import BeautifulSoup

# %%
url ="https://www.cnbc.com/world/?region=world"
page = re.get(url)

data = BeautifulSoup(page.content, 'lxml')

# %%
print(data.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="https://schema.org/WebPage" lang="en" prefix="og=https://ogp.me/ns#">
#  <head>
#   <meta content="telephone=no" name="format-detection"/>
#   <style type="text/css">
# ...

# %%
Headlines = []

for i in data.find_all('a', class_="LatestNews-headline"):
    Headlines.append(i.text)

# %%
Headlines
# Out:
# ['Chinese hospital says half of its staff got Covid ',
#  "Battle for Soledar not over yet, Zelenskyy says; Putin's military reshuffle reflects power struggle",
#  'Experts break down if January really is the right time for a new role  ',
#  'Market for production of clean energy tech could hit $650 billion a year: IEA',
#  'European markets nudge higher; U.S. inflation data to come',
#  "China's reopening set to boost Hong Kong's property market as retail leads the recovery",
#  "Evercore ISI's 2023 top picks include a tech comeback and a car racing play",
#  'Morgan Stanley says these firms take sustainability seriously — and have upside',
#  'Amazon union victory at Staten Island warehouse upheld by federal labor board',
#  'Microsoft looked at Figma but declined to put in an offer as Adobe deal was nearing',
#  "This under-valued exchange offers a 'very good' entry point, strategist says",
#  'Morgan Stanley names its top pick in Chinese tech — and gives it 70% upside ',
# ...

# %%
time= []

for i in data.find_all('span', class_="LatestNews-wrapper"):
    time.append(i.text)

# %%
time
# Out:
# ['1 Hour Ago',
#  '2 Hours Ago',
#  '2 Hours Ago',
#  '4 Hours Ago',
#  '4 Hours Ago',
#  '4 Hours Ago',
#  '6 Hours Ago',
#  '6 Hours Ago',
#  '6 Hours Ago',
#  '7 Hours Ago',
#  '7 Hours Ago',
#  '7 Hours Ago',
#  '7 Hours Ago',
#  '8 Hours Ago',
#  '8 Hours Ago',
#  '8 Hours Ago',
#  '8 Hours Ago',
#  '9 Hours Ago',
#  '9 Hours Ago',
#  '9 Hours Ago',
#  '9 Hours Ago',
#  '10 Hours Ago',
#  '11 Hours Ago',
#  '12 Hours Ago',
#  '12 Hours Ago',
#  '12 Hours Ago',
#  '12 Hours Ago',
#  '13 Hours Ago',
#  '13 Hours Ago',
#  '13 Hours Ago']

# %%
import pandas as pd
latest_news =pd.DataFrame()

latest_news['Latest_News'] = Latest_News
latest_news['time'] = time

latest_news
# Out:
#                                           Latest_News          time
# 0   Sweden is facing its ‘day of reckoning’ as hou...    1 Hour Ago
# 1   CNBC Pro Talks: Portfolio manager Trent Master...   2 Hours Ago
# 2   European markets head for positive open as inv...   2 Hours Ago
# 3   South Korea shares eye-opening statistics to d...   4 Hours Ago
# 4   Investors could find better stock market retur...   4 Hours Ago
# 5   World Bank makes big cut to its 2023 growth ou...   4 Hours Ago
# 6   Tesla plans to spend more than $770 million on...   6 Hours Ago
# 7   This global ETF is the only fund that's posted...   6 Hours Ago
# 8   Citi says stop hoarding cash — and reveals two...   6 Hours Ago
# 9   Cramer's lighting round: Energy Transfer is a ...   7 Hours Ago
# 10  Winter of 'disconnect': Morgan Stanley's Mike ...   7 Hours Ago
# 11  Engineer wanted to make better diapers—now she...   7 Hours Ago
# 12  Stephanie McMahon steps down as WWE co-CEO as ...   7 Hours Ago
# ...

# %%
other_news =[]
for i in data.find_all('div', class_="RiverHeadline-headline RiverHeadline-hasThumbnail"):
    other_news.append(i.text.strip())

# %%
len(other_news)
# Out:
# 20

# %%
time =[]
for i in data.find_all('span', class_="RiverByline-datePublished"):
    time.append(i.text.strip())

# %%
time
# Out:
# ['6 hours ago',
#  '6 hours ago',
#  '2 hours ago',
#  '2 hours ago',
#  '6 hours ago',
#  '6 hours ago',
#  '5 hours ago',
#  '5 hours ago',
#  '6 hours ago',
#  '6 hours ago',
#  '4 hours ago',
#  '4 hours ago',
#  '4 hours ago',
#  '4 hours ago']

# %%
url =[]
for i in data.find_all("div", class_="RiverPlusCard-container"):
    url.append(i.a['href'])
url
# Out:
# ['https://www.cnbc.com/2023/01/12/ukraine-war-live-updates-latest-news-on-russia-and-the-war-in-ukraine.html',
#  'https://www.cnbc.com/2023/01/12/the-world-is-at-the-dawn-of-a-new-industrial-age-iea-says-.html',
#  '/pro/',
#  'https://www.cnbc.com/2023/01/11/covid-news-omicron-xbbpoint1point5-doesnt-have-mutations-known-to-make-people-sicker.html',
#  'https://www.cnbc.com/2023/01/12/chinese-hospital-says-half-of-its-staff-got-covid-.html',
#  '/pro/',
#  'https://www.cnbc.com/2023/01/11/stock-market-news-futures-open-to-close.html',
#  'https://www.cnbc.com/2023/01/11/ukraine-war-russias-fossil-fuel-earnings-fall-in-december.html',
#  'https://www.cnbc.com/2023/01/11/apple-reportedly-considering-touchscreen-mac-laptop-for-2025.html',
#  'https://www.cnbc.com/2023/01/11/south-korea-covid-rules-not-discriminatory-to-chinese-travelers.html',
#  'https://www.cnbc.com/2023/01/11/world-bank-global-economy-to-enter-recession.html',
# ...
